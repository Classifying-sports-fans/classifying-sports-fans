# %%
def accuracy(true, predicted):
    return np.sum(true==predicted)/len(predicted)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
df=pd.read_csv("/content/sports_survey_clean.csv")
columns=pd.read_excel("/content/sports_survey_clean_Column Labels.xlsx")

for i in range(95):
  df=df.rename(columns={df.columns[i]:columns.iloc[i,5]})

from sklearn.model_selection import train_test_split
fan_train, fan_test = train_test_split(df,
                                      shuffle = True,
                                      random_state = 555,
                                      test_size = .2)

# %%
list=['Went to a game','Watched a game at a sports bar','Placed a bet through a sportsbook/casino/bookie','Called into a sports radio show','Talked about games online','Listened to sports radio','Played in a fantasy sports league','Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team','Bet in a group pool, e.g., football squares, survivor leagues','Played daily fantasy']

# %%
correlation_matrix = fan_train.corr()

dfs = []

for i in range(10):
  target_correlations = correlation_matrix[list[i]]
  a=target_correlations.nlargest(10)
  index=a.index
  X_train=fan_train[[index[1],index[2],index[3],index[4],index[5],index[6],index[7],index[8]]]
  y_train=fan_train[[index[0]]]

  from sklearn.linear_model import LogisticRegression
  log_reg = LogisticRegression(penalty=None)
  #X_train=fan_train[[index[1],index[2],index[3],index[4],index[5],index[6],index[7],index[8]]]
  X_train=X_train.to_numpy()
  #y_train=fan_train['Went to a game']
  y_train=y_train.to_numpy()
  log_reg.fit(X_train,y_train)
  y_train_pred_log=log_reg.predict(X_train)
  y_train_pred_log=y_train_pred_log.reshape(8289,1)

  result = {"Model": "logistic", "column2": accuracy(y_train, y_train_pred_log),"y":list[i]}
  dfs.append(result)


  from sklearn.neighbors import KNeighborsClassifier
  from sklearn.pipeline import Pipeline
  from sklearn.preprocessing import StandardScaler

  knn_pipe = Pipeline([('scale', StandardScaler()), ('knn', KNeighborsClassifier(5))])

  knn_pipe.fit(X_train,
           y_train)

  y_train_pred_knn=knn_pipe.predict(X_train)
  y_train_pred_knn=y_train_pred_knn.reshape(8289,1)
  result = {"Model": "Knn", "column2": accuracy(y_train, y_train_pred_knn),"y":list[i]}
  dfs.append(result)

  from sklearn.tree import DecisionTreeClassifier
  from sklearn import tree

  tree_clf = DecisionTreeClassifier(max_depth=10,random_state= 216)

  ## fit the classifier
  tree_clf.fit(X_train, y_train)

  y_train_pred_dt=tree_clf.predict(X_train)
  y_train_pred_dt=y_train_pred_dt.reshape(8289,1)
  result = {"Model": "DT", "column2": accuracy(y_train, y_train_pred_dt),"y":list[i]}
  dfs.append(result)

  ## import model objects
  from sklearn.tree import DecisionTreeClassifier
  from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
  from sklearn.metrics import accuracy_score
  tree = DecisionTreeClassifier(max_depth = 10, random_state= 216)
  rf = RandomForestClassifier(n_estimators = 500,min_samples_leaf = 5,max_features = 2,bootstrap= True,max_samples = 500,random_state = 216)
  et = ExtraTreesClassifier(n_estimators = 500,min_samples_leaf = 5, max_features = 2, random_state = 216)

  tree.fit(X_train, y_train)

  ## rf and et may take slightly longer because we are fitting many trees
  rf.fit(X_train, y_train)
  et.fit(X_train, y_train)

  trees_pred=tree.predict(X_train)
  trees_pred=trees_pred.reshape(8289,1)
  rf_preds = rf.predict(X_train)
  rf_preds=rf_preds.reshape(8289,1)
  et_preds = et.predict(X_train)
  et_preds=et_preds.reshape(8289,1)

  result = {"Model": "tree", "column2": accuracy(y_train, trees_pred),"y":list[i]}
  dfs.append(result)

  result = {"Model": "rf", "column2": accuracy(y_train, rf_preds),"y":list[i]}
  dfs.append(result)

  result = {"Model": "et", "column2": accuracy(y_train, et_preds),"y":list[i]}
  dfs.append(result)

  from sklearn.ensemble import AdaBoostClassifier

  ## Import the base classifier
  from sklearn.tree import DecisionTreeClassifier


  ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=3),n_estimators=100,algorithm = 'SAMME',learning_rate = 0.5,random_state=123)
  ada_clf.fit(X_train, y_train)
  ada_pred=ada_clf.predict(X_train)
  ada_pred=ada_pred.reshape(8289,1)
  result = {"Model": "Ada", "column2": accuracy(y_train, ada_pred),"y":list[i]}
  dfs.append(result)

  from sklearn.ensemble import GradientBoostingRegressor

  n_trees = 200
  gb = GradientBoostingRegressor(max_depth=1,
                               n_estimators=n_trees)

  ## fit the booster
  gb.fit(X_train, y_train)

  gb_pred = gb.predict(X_train)
  gb_pred=np.where(gb_pred < 0.5, 0, 1)
  gb_pred=gb_pred.reshape(8289,1)
  result = {"Model": "GB", "column2": accuracy(y_train, gb_pred),"y":list[i]}
  dfs.append(result)


  # XGBoost
  import xgboost

  xgb_reg1 = xgboost.XGBRegressor(learning_rate=.5,max_depth=7,n_estimators=15)
  xgb_reg1.fit(X_train, y_train)

  xgb_pred = xgb_reg1.predict(X_train)
  xgb_pred=np.where(xgb_pred < 0.5, 0, 1)
  xgb_pred=xgb_pred.reshape(8289,1)

  result = {"Model": "XGB", "column2": accuracy(y_train, xgb_pred),"y":list[i]}
  dfs.append(result)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# <ipython-input-15-d61195c7d168>:64: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)
# <ipython-input-15-d61195c7d168>:65: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   et.fit(X_train, y_train)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
dfs
# Out:
# [{'Model': 'logistic', 'column2': 0.7146821088189166, 'y': 'Went to a game'},
#  {'Model': 'Knn', 'column2': 0.7716250452406804, 'y': 'Went to a game'},
#  {'Model': 'DT', 'column2': 0.7616117746410906, 'y': 'Went to a game'},
#  {'Model': 'tree', 'column2': 0.7616117746410906, 'y': 'Went to a game'},
#  {'Model': 'rf', 'column2': 0.7205935577271082, 'y': 'Went to a game'},
#  {'Model': 'et', 'column2': 0.7417058752563639, 'y': 'Went to a game'},
#  {'Model': 'Ada', 'column2': 0.7169743032935215, 'y': 'Went to a game'},
#  {'Model': 'GB', 'column2': 0.7158885269634455, 'y': 'Went to a game'},
#  {'Model': 'XGB', 'column2': 0.7785016286644951, 'y': 'Went to a game'},
#  {'Model': 'logistic',
#   'column2': 0.7133550488599348,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'Knn',
#   'column2': 0.7735553142719267,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'DT',
#   'column2': 0.7658342381469417,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'tree',
#   'column2': 0.7658342381469417,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'rf',
#   'column2': 0.7199903486548438,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'et',
#   'column2': 0.7462902642055737,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'Ada',
#   'column2': 0.7154059597056339,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'GB',
#   'column2': 0.7137169743032935,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'XGB',
#   'column2': 0.7944263481722765,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'logistic',
#   'column2': 0.8489564483049825,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'Knn',
#   'column2': 0.8820123054650741,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'DT',
#   'column2': 0.8957654723127035,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'tree',
#   'column2': 0.8957654723127035,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'rf',
#   'column2': 0.8547472553987212,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'et',
#   'column2': 0.8728435275666546,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'Ada',
#   'column2': 0.8504041500784172,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'GB',
#   'column2': 0.8529376281819279,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'XGB',
#   'column2': 0.9226685969356979,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'logistic',
#   'column2': 0.9591024249004705,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'Knn',
#   'column2': 0.9613946193750754,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'DT',
#   'column2': 0.9779225479551212,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'tree',
#   'column2': 0.9779225479551212,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'rf',
#   'column2': 0.9595849921582821,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'et',
#   'column2': 0.9600675594160936,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'Ada',
#   'column2': 0.9589817830860176,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'GB',
#   'column2': 0.9595849921582821,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'XGB',
#   'column2': 0.9763542043672336,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'logistic',
#   'column2': 0.7326577391723972,
#   'y': 'Talked about games online'},
#  {'Model': 'Knn',
#   'column2': 0.7809144649535529,
#   'y': 'Talked about games online'},
#  {'Model': 'DT',
#   'column2': 0.7921341536976716,
#   'y': 'Talked about games online'},
#  {'Model': 'tree',
#   'column2': 0.7921341536976716,
#   'y': 'Talked about games online'},
#  {'Model': 'rf',
#   'column2': 0.738327904451683,
#   'y': 'Talked about games online'},
#  {'Model': 'et',
#   'column2': 0.7683677162504524,
#   'y': 'Talked about games online'},
#  {'Model': 'Ada',
#   'column2': 0.7347086500180963,
#   'y': 'Talked about games online'},
#  {'Model': 'GB',
#   'column2': 0.7368802026782483,
#   'y': 'Talked about games online'},
#  {'Model': 'XGB',
#   'column2': 0.8193992037640246,
#   'y': 'Talked about games online'},
#  {'Model': 'logistic',
#   'column2': 0.6871757751236579,
#   'y': 'Listened to sports radio'},
#  {'Model': 'Knn',
#   'column2': 0.7573893111352394,
#   'y': 'Listened to sports radio'},
#  {'Model': 'DT',
#   'column2': 0.7604053564965617,
#   'y': 'Listened to sports radio'},
#  {'Model': 'tree',
#   'column2': 0.7604053564965617,
#   'y': 'Listened to sports radio'},
#  {'Model': 'rf',
#   'column2': 0.6910363131861503,
#   'y': 'Listened to sports radio'},
#  {'Model': 'et',
#   'column2': 0.7342260827602847,
#   'y': 'Listened to sports radio'},
#  {'Model': 'Ada',
#   'column2': 0.6895886114127157,
#   'y': 'Listened to sports radio'},
#  {'Model': 'GB',
#   'column2': 0.6887441187115454,
#   'y': 'Listened to sports radio'},
#  {'Model': 'XGB',
#   'column2': 0.7845337193871396,
#   'y': 'Listened to sports radio'},
#  {'Model': 'logistic',
#   'column2': 0.8508867173362288,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'Knn',
#   'column2': 0.9009530703341778,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'DT',
#   'column2': 0.9065025937990108,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'tree',
#   'column2': 0.9065025937990108,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'rf',
#   'column2': 0.8828567981662444,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'et',
#   'column2': 0.89311135239474,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'Ada',
#   'column2': 0.8780311255881288,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'GB',
#   'column2': 0.8762214983713354,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'XGB',
#   'column2': 0.9278561949571722,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'logistic',
#   'column2': 0.9227892387501508,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'Knn',
#   'column2': 0.9278561949571722,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'DT',
#   'column2': 0.9486065870430691,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'tree',
#   'column2': 0.9486065870430691,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'rf',
#   'column2': 0.9200144770177343,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'et',
#   'column2': 0.9256846422970202,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'Ada',
#   'column2': 0.9227892387501508,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'GB',
#   'column2': 0.9221860296778863,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'XGB',
#   'column2': 0.9523464832911087,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'logistic',
#   'column2': 0.8174689347327784,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'Knn',
#   'column2': 0.8512486427795874,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'DT',
#   'column2': 0.8606587043069128,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'tree',
#   'column2': 0.8606587043069128,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'rf',
#   'column2': 0.822294607310894,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'et',
#   'column2': 0.8383399686331282,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'Ada',
#   'column2': 0.8159005911448908,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'GB',
#   'column2': 0.820002412836289,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'XGB',
#   'column2': 0.8837012908674147,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'logistic',
#   'column2': 0.8835806490529617,
#   'y': 'Played daily fantasy'},
#  {'Model': 'Knn', 'column2': 0.9063819519845578, 'y': 'Played daily fantasy'},
#  {'Model': 'DT', 'column2': 0.9223066714923392, 'y': 'Played daily fantasy'},
#  {'Model': 'tree', 'column2': 0.9223066714923392, 'y': 'Played daily fantasy'},
#  {'Model': 'rf', 'column2': 0.884425141754132, 'y': 'Played daily fantasy'},
#  {'Model': 'et', 'column2': 0.8996260103751961, 'y': 'Played daily fantasy'},
#  {'Model': 'Ada', 'column2': 0.8863554107853782, 'y': 'Played daily fantasy'},
#  {'Model': 'GB', 'column2': 0.8846664253830377, 'y': 'Played daily fantasy'},
#  {'Model': 'XGB', 'column2': 0.9376281819278562, 'y': 'Played daily fantasy'}]

# %%
## From Lecture 9 part V
ensemblers = {
    'log_reg' : LogisticRegression(penalty=None),
    #'knn_pipe': Pipeline([('scale', StandardScaler()), ('knn', KNeighborsClassifier(5))]),
    'tree_clf': DecisionTreeClassifier(max_depth=10,random_state= 216),
    'rf': RandomForestClassifier(n_estimators = 500,min_samples_leaf = 5,max_features = 2,bootstrap= True,max_samples = 500,random_state = 216),
    'et': ExtraTreesClassifier(n_estimators = 500,min_samples_leaf = 5, max_features = 2, random_state = 216),
    'ada_clf': AdaBoostClassifier(DecisionTreeClassifier(max_depth=3),n_estimators=100,algorithm = 'SAMME',learning_rate = 0.5,random_state=123),
    'gb': GradientBoostingRegressor(max_depth=1,n_estimators=n_trees),
    'xgb_reg1':xgboost.XGBRegressor(learning_rate=.5,max_depth=7,n_estimators=15)
}

# %%
correlation_matrix = fan_train.corr()

dfs = []

for i in range(10):
  target_correlations = correlation_matrix[list[i]]
  a=target_correlations.nlargest(10)
  print(a,)
# Out:
# Went to a game                                                                                               1.000000
# Watched a game at a sports bar                                                                               0.307843
# Fan_magnitude                                                                                                0.237597
# Wore my team's jersey                                                                                        0.237232
# Watched a game at a friend's home                                                                            0.234121
# Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team    0.231266
# Played in a fantasy sports league                                                                            0.215958
# Listened to sports radio                                                                                     0.198090
# Bet in a group pool, e.g., football squares, survivor leagues                                                0.194740
# Fan of MLB                                                                                                   0.187358
# Name: Went to a game, dtype: float64
# Watched a game at a sports bar                                   1.000000
# Watched a game at a friend's home                                0.353891
# Went to a game                                                   0.307843
# Bet in a group pool, e.g., football squares, survivor leagues    0.252752
# Interested in  Betting?                                          0.244778
# Fan_magnitude                                                    0.234423
# How often will you bet on NFL                                    0.232656
# Placed a bet through a sportsbook/casino/bookie                  0.224481
# Played in a fantasy sports league                                0.212652
# Wore my team's jersey                                            0.208858
# Name: Watched a game at a sports bar, dtype: float64
# Placed a bet through a sportsbook/casino/bookie                  1.000000
# How often will you bet on NFL                                    0.549492
# Interested in  Betting?                                          0.487467
# Bet in a group pool, e.g., football squares, survivor leagues    0.373068
# Played daily fantasy                                             0.364685
# Played in a fantasy sports league                                0.324852
# How many fantasy football leagues will you play in?              0.318061
# Fan_magnitude                                                    0.311980
# Fan of Combat Spots                                              0.242334
# Talked about games online                                        0.226070
# Name: Placed a bet through a sportsbook/casino/bookie, dtype: float64
# Called into a sports radio show                                                                              1.000000
# How many fantasy football leagues will you play in?                                                          0.220847
# Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team    0.201872
# Fan_magnitude                                                                                                0.198354
# How often will you bet on NFL                                                                                0.176849
# Do you subscribe to NFL Sunday Ticket                                                                        0.166327
# Interested in  Betting?                                                                                      0.165945
# Fan of MLS                                                                                                   0.154874
# Do you subscribe to NFL Red Zone                                                                             0.147696
# Played in a fantasy sports league                                                                            0.147554
# Name: Called into a sports radio show, dtype: float64
# Talked about games online                              1.000000
# Interested in  Betting?                                0.322065
# Fan_magnitude                                          0.311422
# How often will you bet on NFL                          0.281591
# How many fantasy football leagues will you play in?    0.264947
# Played daily fantasy                                   0.253954
# Played in a fantasy sports league                      0.231504
# Fan of Combat Spots                                    0.226811
# Placed a bet through a sportsbook/casino/bookie        0.226070
# Fan of International Soccer                            0.225982
# Name: Talked about games online, dtype: float64
# Listened to sports radio                       1.000000
# Fan_magnitude                                  0.323883
# Fan of MLB                                     0.236868
# Played in a fantasy sports league              0.233953
# Interested in  Betting?                        0.224381
# Talked about games in person/over the phone    0.224160
# Fan of College Basketball                      0.209661
# Played daily fantasy                           0.206595
# Watched a game at a sports bar                 0.205762
# Talked about games online                      0.205662
# Name: Listened to sports radio, dtype: float64
# Played in a fantasy sports league                                1.000000
# How many fantasy football leagues will you play in?              0.602040
# Played daily fantasy                                             0.512715
# How often will you bet on NFL                                    0.365766
# Interested in  Betting?                                          0.360797
# Bet in a group pool, e.g., football squares, survivor leagues    0.345485
# Placed a bet through a sportsbook/casino/bookie                  0.324852
# Fan_magnitude                                                    0.317610
# Listened to sports radio                                         0.233953
# Talked about games online                                        0.231504
# Name: Played in a fantasy sports league, dtype: float64
# Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team    1.000000
# Fan_magnitude                                                                                                0.237570
# How many fantasy football leagues will you play in?                                                          0.236847
# Went to a game                                                                                               0.231266
# Do you subscribe to NFL Sunday Ticket                                                                        0.213800
# How often will you bet on NFL                                                                                0.212671
# Played daily fantasy                                                                                         0.210091
# Called into a sports radio show                                                                              0.201872
# Interested in  Betting?                                                                                      0.199181
# Do you subscribe to NFL Red Zone                                                                             0.198126
# Name: Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team, dtype: float64
# Bet in a group pool, e.g., football squares, survivor leagues    1.000000
# How often will you bet on NFL                                    0.418577
# Interested in  Betting?                                          0.384100
# Placed a bet through a sportsbook/casino/bookie                  0.373068
# Played in a fantasy sports league                                0.345485
# How many fantasy football leagues will you play in?              0.340909
# Played daily fantasy                                             0.327078
# Fan_magnitude                                                    0.277308
# Watched a game at a sports bar                                   0.252752
# Watched a game at a friend's home                                0.227755
# Name: Bet in a group pool, e.g., football squares, survivor leagues, dtype: float64
# Played daily fantasy                                             1.000000
# How many fantasy football leagues will you play in?              0.518328
# Played in a fantasy sports league                                0.512715
# How often will you bet on NFL                                    0.429653
# Interested in  Betting?                                          0.389379
# Placed a bet through a sportsbook/casino/bookie                  0.364685
# Bet in a group pool, e.g., football squares, survivor leagues    0.327078
# Fan_magnitude                                                    0.323971
# Talked about games online                                        0.253954
# Fan of Combat Spots                                              0.224897
# Name: Played daily fantasy, dtype: float64

# %%
correlation_matrix = fan_train.corr()


for i in range(10):
  target_correlations = correlation_matrix[list[i]]
  a=target_correlations.nlargest(10)
  index=a.index
  X_train=fan_train[[index[1],index[2],index[3],index[4],index[5],index[6],index[7],index[8]]]
  y_train=fan_train[[index[0]]]

  xgb_reg1 = xgboost.XGBRegressor(learning_rate=.5,max_depth=7,n_estimators=15)
  xgb_reg1.fit(X_train, y_train)
  X_test=fan_test[[index[1],index[2],index[3],index[4],index[5],index[6],index[7],index[8]]]

  xgb_pred = xgb_reg1.predict(X_test)
  xgb_pred=np.where(xgb_pred < 0.5, 0, 1)
  xgb_pred=xgb_pred.reshape(2073,1)
  y_test=fan_test[[index[0]]]

  result = {"Model": "XGB", "column2": accuracy(y_test, xgb_pred),"y":list[i]}
  dfs.append(result)

# %%
dfs
# Out:
# [{'Model': 'XGB',
#   'column2': Went to a game    0.700434
#   dtype: float64,
#   'y': 'Went to a game'},
#  {'Model': 'XGB',
#   'column2': Watched a game at a sports bar    0.684033
#   dtype: float64,
#   'y': 'Watched a game at a sports bar'},
#  {'Model': 'XGB',
#   'column2': Placed a bet through a sportsbook/casino/bookie    0.834057
#   dtype: float64,
#   'y': 'Placed a bet through a sportsbook/casino/bookie'},
#  {'Model': 'XGB',
#   'column2': Called into a sports radio show    0.956585
#   dtype: float64,
#   'y': 'Called into a sports radio show'},
#  {'Model': 'XGB',
#   'column2': Talked about games online    0.708152
#   dtype: float64,
#   'y': 'Talked about games online'},
#  {'Model': 'XGB',
#   'column2': Listened to sports radio    0.63917
#   dtype: float64,
#   'y': 'Listened to sports radio'},
#  {'Model': 'XGB',
#   'column2': Played in a fantasy sports league    0.864448
#   dtype: float64,
#   'y': 'Played in a fantasy sports league'},
#  {'Model': 'XGB',
#   'column2': Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team    0.918958
#   dtype: float64,
#   'y': 'Purchased a multi-game ticket package (e.g., season tickets, partial plan) for a professional sports team'},
#  {'Model': 'XGB',
#   'column2': Bet in a group pool, e.g., football squares, survivor leagues    0.809455
#   dtype: float64,
#   'y': 'Bet in a group pool, e.g., football squares, survivor leagues'},
#  {'Model': 'XGB',
#   'column2': Played daily fantasy    0.853835
#   dtype: float64,
#   'y': 'Played daily fantasy'}]
